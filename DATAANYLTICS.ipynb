# %% [markdown]
# # Step 0: EDA
#
#
#
# ## What is EDA?
#
# > > ### __`EDA stands for Exploratory Data Analysis`__<br>
# __EDA is actually an approach to understand the dataset on which we can draw or take descission and understand the problem well.__
# > ####  E -> Exploring :
# >` Exploring The datasets ,problems statements ,pattern found in datasets, draw hypothisis, suitablity of models , statistical anaylsis etc.. `
# > ####  D -> DATA :
# >` Data is a valid fact used for the purpose of the solving the problems , Say about the numerical story or real story of the problem we are solving. `
# > ####  A -> Analysis :
# >` Applying Ayanltical skills , undertsnading the data, datasets , problems,approach of solution, extension of the problems. `
# ***
#
#
# <img src="https://miro.medium.com/max/1400/1*3sr-fMg4S_yEncGsIjyG9A.png" max-width= 50%;  height= auto; />
#
# The National Institute of Standards and Technology (NIST) describes EDA as an approach to data analysis, not a model, that uses these techniques:
#
# >1. Maximize insights into a dataset.
# >2. Uncover underlying structures.
# >3. Extract important variables.
# >4. Detect outliers and anomalies.
# >5. Test underlying assumptions.
# >6. Develop parsimonious models.
# >7. Determine optimal factor settings.
#
# NIST explains that EDA is an approach to data analysis that “postpones the usual assumptions about what kind of model the data \[follows\]” and allows the data to reveal its underlying structure and model.
# ***
# EDA is typically used for these four goals:
#
# >- Exploring a single variable and looking at trends over time.
# >- Checking data for errors.
# >- Checking assumptions.
# >- Looking at relationships between variables.
#
# [Source: Mastersindatascience](https://www.mastersindatascience.org/learning/what-is-exploratory-data-analysis/)

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/59SFeXcRpLE" title="What is EDA" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# <hr>
# <iframe width="560" height="315" src="https://www.youtube.com/embed/a4KiExvYJKo?start=28" title="What is EDA?" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/59SFeXcRpLE" title="What is EDA" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# <hr>
# <iframe width="560" height="315" src="https://www.youtube.com/embed/a4KiExvYJKo?start=28" title="What is EDA?" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ---
#
# ### Main Reason For EDA
#
# > #### Detection of mistakes
# >`In The data or machine learning or deep learning model something when wrong .`
#
#
# > #### Checking of assumptions
# >` To Prove Our thoughts on the model and story is correct. It's not like we are making  flue and got correct result by chance.`
#
# > #### Preliminary selection of appropriate models
# >` Limiting the choices for models . Chooing only requred tools for probelm solving. `
#
# > #### Determining relationships among the explanatory variables
# >` Finding what replaition is between your varibles `
#
# > #### Assessing the direction and rough size of relationships between explanatory and outcome variables.
# >` Using the relationship for our model benifits `
#
#
#
# <img src="https://imgur.com/zlBFq4G.jpeg" max-width= 50%;  height= auto;/>
#
# >__` Learning happens when you observe a phenomena and recognize a pattern. You try to understand this pattern by finding out if there is any relationship the entities involved in that phenomena `__
#
# <img src="https://imgur.com/6lbm6cr.jpeg" max-width= 50%;  height= auto;/>
#
# [Krish Naik](https://www.youtube.com/watch?v=ioN1jcWxbv8&list=PLZoTAELRMXVPQyArDHyQVjQxjj_YmEuO9)
#
# [Ravi kumar playlist for eda ](https://www.youtube.com/watch?v=wLUdYazCqDQ&list=PLvcxya_kQ6n3GhRNDc-6Q7aZ3fZPBxW20)
#
# <img src="https://149695847.v2.pressablecdn.com/wp-content/uploads/2017/06/p7p9i.jpg" max-width= 50%;  height= auto;/>
#
# ---
#
# ## DATA Point:
#
# DATA
# : <strong>Data are individual facts, statistics, or items of information, often numeric.</strong>
# In a more technical sense, data are a set of values of qualitative or quantitative variables about one or more persons or objects,while a datum (singular of data) is a single value of a single variable.
#
# In simple words data is a valid fact record or information given to us or stored.
# <br>
# <img src="https://miro.medium.com/max/1000/1*WACiczYwdWTnJ94mnizS4Q.jpeg" max-width= 50%;  height= auto;/>
# <br>[Source : wikipedia](https://en.wikipedia.org/wiki/Data)
# ***
#
# > __A data point is a discrete unit of information.
# In a general sense, any single fact is a data point. In a statistical or analytical context, a data point is usually derived from a measurement or research and can be represented numerically and/or graphically. The term data point is roughly equivalent to datum, the singular form of data .__
# <br>[Source : techtarget](https://www.techtarget.com/whatis/definition/data-point)
#
# In data analysis and statistics, a data point is a piece of information that describes one unit of observation, at one point in time, at the data collection level. It most commonly appears as one cell in a data table.
# <br>[Source:analystanswers ](https://analystanswers.com/data-point-definition-types-examples/#:~:text=In%20data%20analysis%20and%20statistics%2C%20a%20data%20point,data%20set%2C%E2%80%9D%20but%20this%20is%20not%20entirely%20accurate.)
#
# >Data points, also known as data items, are the atomic state of data.
#
# A data point or observation is a set of one or more measurements on a single member of the unit of observation.
# <br>[Source : Wikipedia](https://en.wikipedia.org/wiki/Unit_of_observation#Data_point)
# ***
#
# ---
#
# ## Vector:
# Vector :A vector is a mathematical object that encodes a length and direction.
# Vectors are commonly used in machine learning as they lend a convenient way to organize data.  Often one of the very first steps in making a machine learning model is vectorizing the data.
#
# ### Vectors vs. Scalars
#
# A vector is a data structure with at least two components, as opposed to a scalar, which has just one.<br>
#  _For example, a vector can represent velocity, an idea that combines speed and direction: wind velocity = (50mph, 35 degrees North East)._<br>
# A scalar, on the other hand, can represent something with one value _like temperature or height: 50 degrees Celsius, 180 centimeters._<br>
# Therefore, we can represent two-dimensional vectors as arrows on an x-y graph, with the coordinates x and y each representing one of the vector’s values.
# <br> [Source : deepai](https://deepai.org/machine-learning-glossary-and-terms/vector)
#
# ---
#
# ## Observation
#
# A statement based on something one has seen, heard, or noticed.
#
# Observation is the active acquisition of information from a primary source. In living beings, observation employs the senses.
# <br>[Source : Wikipedia](https://en.wikipedia.org/wiki/Observation)
#
# >__` Every learning, fundamentally, is a model expressing a pattern in a set of observations. If there is no conceivable pattern, there will be no learning. `__<br><br>
# >__`No model or learning reflects “true” or “absolute” reality. Every model or learning is an approximation of observed reality.`__
#
# #### WHY DATA as vector?
#
# `“ We all are vectors. Many of us are still in search of direction ”` :joy:
#
#
# DATA as vector because vector deals with both magnitude and direction and not just limited to 3D axis
#
# <br> [Source : towardsdatascience ](https://towardsdatascience.com/why-data-is-represented-as-a-vector-in-data-science-problems-a195e0b17e99)
#
# ## Future Info
# 1. [EDA Lesson 1 (b)](https://online.stat.psu.edu/stat508/book/export/html/632)
# <br>
# 2.[Data Science: Reality Doesn't Meet Expectations](https://dfrieds.com/articles/data-science-reality-vs-expectations.html) <br>
#
# ## Dataset
# Dataset :A collection of related sets of information that is composed of separate elements but can be manipulated as a unit by a computer.
# A data set (or dataset) is a collection of data
#
# A data set is a collection of related, discrete items of related data that may be accessed individually or in combination or managed as a whole entity.
#
# <br> [Source :techtarget ](https://www.techtarget.com/whatis/definition/data-set)<br>
# <br> [Source :Wikipedia](https://en.wikipedia.org/wiki/Data_set)
#
# ---
#
# ## Feature/Variable/Input-variable/Dependent-Variable
#
#
# <img src="https://cdn.corporatefinanceinstitute.com/assets/dependent-variable-1024x595.jpeg" width= 50%;  height= 50%;/>
# The variables which depend on other variables or factors.
#
# Dependent variables are variables whose changes depend solely on another variable—usually the independent variable. That is, the value of the dependent variable will only change if the independent variable changes
#
# The dependent variable (DV) is what you want to use the model to explain or predict. The values of this variable depend on other variables. It is the outcome that you’re studying. It’s also known as the response variable, outcome variable, and left-hand variable
#
# <br> [Source :formpl](https://www.formpl.us/blog/dependent-independent-variables)
#
#
#
# ## Label/Indepdendent-variable/Output-varible/Class/Class-label/Response label
#
# The variable that are not affected by the other variables
#
# Independent variables are variables whose variations do not depend on another variable. They are controlled inputs, whose variation depends on the researcher or individual working with the variables.
#
#
#
# <br> [Source : wikipedia](https://en.wikipedia.org/wiki/Dependent_and_independent_variables)
#
# How to Identify Independent and Dependent Variables
#
# <br> [Source : statisticsbyjim](https://statisticsbyjim.com/regression/independent-dependent-variables/)
#
# <br> [Tutorial : khanacademy](https://www.khanacademy.org/math/cc-sixth-grade-math/cc-6th-equations-and-inequalities/cc-6th-dependent-independent/v/dependent-and-independent-variables-exercise-example-1)
#
# <br> [Source : scribbr](https://www.scribbr.com/methodology/independent-and-dependent-variables/)

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/i9j_VUMq5yg" title="Independent and Dependent Variables" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/i9j_VUMq5yg" title="Independent and Dependent Variables" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## What is a 1-D vector: Scalar
#
# A scalar with a unit is a 1-dimensional (axial) vector; changing the basis corresponds to changing the unit. A number (without a unit) is not a 1-dimensional vector in the terminology used by physicists. However, it is a 1-dimensional vector in the terminology used in linear algebra.
#
# A scalar is defined to be invariant under transformations of the coordinate system. Thus, a vector in one dimension is not a scalar.
#
# Time is a "parameter", or a component of a 4-vector in special relativity. In classical mechanics, it is essentially a one-dimensional vector.
# ***
#
# Optional
#
# ---
# A vector in a 1D space is not a scalar. But if we choose a basis (which in this case consists only in one vector, say E), any other vector is of the form vE, with v a scalar. So we can identify the 1D vector space with R, but the identification depends on the choice of E.
#
# In the case of the time, things are similar. For the Minkowski spacetime, consider an orthonormal basis, consisting in three spacelike vectors and one timelike vector. This basis allows us to express any event in terms of three space coordinates, and one time coordinate. The time coordinate is a scalar, and can indeed be positive or negative. For curved spacetime, the things get more difficult. The spacetime is no longer a vector space. We use coordinates, which are no longer obtained from vector frames. Sometimes they can't even be global, so we have to take them local (limited to a subset of the spacetime).
#
# [quora](https://www.quora.com/Is-a-one-dimensional-vector-a-scalar)<br>
# [stackexchange](https://physics.stackexchange.com/questions/35562/is-a-1d-vector-also-a-scalar)
# [12steps](https://miro.medium.com/max/1400/1*DWpwjk-yqNliqQlkqBKfUw.jpeg)

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/ihNZlp7iUHE" title="IntoDuction to vector and scalar" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/ihNZlp7iUHE" title="IntoDuction to vector and scalar" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# #  1. Iris Flower dataset

# %%
import mysql.connector
import pandas as pd

# %%
import mysql.connector as sql
db_connection = sql.connect(host='localhost', port= '3306', database='sakila', user='root', password='rajan@123', auth_plugin = 'mysql_native_password')
db_cursor = db_connection.cursor()
db_cursor.execute('SELECT * FROM actor')
table_rows = db_cursor.fetchall()
for i in table_rows:
    print (i)
# Out:
# (1, 'PENELOPE', 'GUINESS', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (2, 'NICK', 'WAHLBERG', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (3, 'ED', 'CHASE', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (4, 'JENNIFER', 'DAVIS', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (5, 'JOHNNY', 'LOLLOBRIGIDA', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (6, 'BETTE', 'NICHOLSON', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (7, 'GRACE', 'MOSTEL', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (8, 'MATTHEW', 'JOHANSSON', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (9, 'JOE', 'SWANK', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (10, 'CHRISTIAN', 'GABLE', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (11, 'ZERO', 'CAGE', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (12, 'KARL', 'BERRY', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (13, 'UMA', 'WOOD', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (14, 'VIVIEN', 'BERGEN', datetime.datetime(2006, 2, 15, 4, 34, 33))
# ...

# %%
# %%html
# <hr>
# <iframe width="560" height="315" src="https://www.youtube.com/embed/wwsizzg6UjU?start=90" title="Practical Statistics for Data Scientists" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
#
# <hr>
# <br>
# <iframe width="560" height="315" src="https://www.youtube.com/embed/hjysbs1Up_0" title="Exploratory Data Analysis" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <hr>
# <iframe width="560" height="315" src="https://www.youtube.com/embed/wwsizzg6UjU?start=90" title="Practical Statistics for Data Scientists" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
#
# <hr>
# <br>
# <iframe width="560" height="315" src="https://www.youtube.com/embed/hjysbs1Up_0" title="Exploratory Data Analysis" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
